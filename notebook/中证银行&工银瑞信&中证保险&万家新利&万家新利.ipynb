# %%
from apollo.src.module.aip_mod import invest_week_with_start_interval
from apollo.src.plot.aip_plot import show_diff_box_plot, show_diff_violin_plot, show_one_box_plot

# %%
# 中证银行 161121 近期开始买
df_161121_new = invest_week_with_start_interval(code='161121', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 中证银行 161121 很早开始买
df_161121_old = invest_week_with_start_interval(code='161121', 
                                            start_interval=('2020-01-08', '2020-04-01'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 23:00:20 - aip_service.py - 42 - INFO: 统计完成，161121 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 23:00:42 - aip_service.py - 42 - INFO: 统计完成，161121 每周定投100，起始日区间为('2020-01-08', '2020-04-01'), 结束日为2021-08-09.

# %%
# 工银瑞信 000251 近期开始买
df_000251_new = invest_week_with_start_interval(code='000251', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 工银瑞信 000251 很早开始买
df_000251_old = invest_week_with_start_interval(code='000251', 
                                            start_interval=('2020-01-08', '2020-04-01'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 23:01:25 - aip_service.py - 42 - INFO: 统计完成，000251 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 23:01:47 - aip_service.py - 42 - INFO: 统计完成，000251 每周定投100，起始日区间为('2020-01-08', '2020-04-01'), 结束日为2021-08-09.

# %%
# 中证保险 167301 近期开始买
df_167301_new = invest_week_with_start_interval(code='167301', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 中证保险 167301 很早开始买
df_167301_old = invest_week_with_start_interval(code='167301', 
                                            start_interval=('2020-01-08', '2020-04-01'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 23:02:13 - aip_service.py - 42 - INFO: 统计完成，167301 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 23:02:34 - aip_service.py - 42 - INFO: 统计完成，167301 每周定投100，起始日区间为('2020-01-08', '2020-04-01'), 结束日为2021-08-09.

# %%
# 万家新利 519191 近期开始买
df_519191_new = invest_week_with_start_interval(code='519191', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 万家新利 519191 很早开始买
df_519191_old = invest_week_with_start_interval(code='519191', 
                                            start_interval=('2020-01-08', '2020-04-01'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 23:02:49 - aip_service.py - 42 - INFO: 统计完成，519191 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 23:03:14 - aip_service.py - 42 - INFO: 统计完成，519191 每周定投100，起始日区间为('2020-01-08', '2020-04-01'), 结束日为2021-08-09.

# %%
# 万家精选 519185 近期开始买
df_519185_new = invest_week_with_start_interval(code='519185', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 万家精选 519185 很早开始买
df_519185_old = invest_week_with_start_interval(code='519185', 
                                            start_interval=('2020-01-08', '2020-04-01'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 23:03:26 - aip_service.py - 42 - INFO: 统计完成，519185 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 23:04:32 - aip_service.py - 42 - INFO: 统计完成，519185 每周定投100，起始日区间为('2020-01-08', '2020-04-01'), 结束日为2021-08-09.

# %%
show_diff_box_plot({'中证银行-近期买':df_161121_new, 
                    '中证银行-早期买':df_161121_old})

# %%
show_diff_box_plot({'工银瑞信-近期买':df_000251_new, 
                    '工银瑞信-早期买':df_000251_old})

# %%
show_diff_box_plot({'中证保险-近期买':df_167301_new, 
                    '中证保险-早期买':df_519191_old})

# %%
show_one_box_plot({'万家新利-近期买':df_519191_new, 
                    '万家新利-早期买':df_519191_old, 
                    '万家精选-近期买':df_519185_new,
                    '万家精选-早期买':df_519185_old})

# %%
show_one_box_plot({'中证银行-近期买':df_161121_new,
                    '工银瑞信-近期买':df_000251_new, 
                    '中证保险-近期买':df_167301_new, 
                    '万家新利-近期买':df_519191_new,})

# %%
show_diff_violin_plot({'中证银行-近期买':df_161121_new,
                    '工银瑞信-近期买':df_000251_new, 
                    '中证保险-近期买':df_167301_new, 
                    '万家新利-近期买':df_519191_new,})
