# %%
from apollo.src.service.aip_service import invest_week_with_start_interval
from apollo.src.plot.plot_aip import show_diff_box_plot, show_diff_violin_plot, show_one_box_plot

# %%
# 易方达蓝筹 005827 高点开始买
df_005827_high = invest_week_with_start_interval(code='005827', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 易方达蓝筹 005827 低点开始买
df_005827_low = invest_week_with_start_interval(code='005827', 
                                            start_interval=('2020-11-02', '2020-12-15'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 22:43:38 - aip_service.py - 42 - INFO: 统计完成，005827 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 22:44:12 - aip_service.py - 42 - INFO: 统计完成，005827 每周定投100，起始日区间为('2020-11-02', '2020-12-15'), 结束日为2021-08-09.

# %%
# 景顺长城 162605 高点开始买
df_162605_high = invest_week_with_start_interval(code='162605', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 景顺长城 162605 低点开始买
df_162605_low = invest_week_with_start_interval(code='162605', 
                                            start_interval=('2020-11-02', '2020-12-15'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 22:44:51 - aip_service.py - 42 - INFO: 统计完成，162605 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 22:46:11 - aip_service.py - 42 - INFO: 统计完成，162605 每周定投100，起始日区间为('2020-11-02', '2020-12-15'), 结束日为2021-08-09.

# %%
show_diff_violin_plot({'蓝筹高点买':df_005827_high, 
                    '蓝筹低点买':df_005827_low, 
                    '长城高点买':df_162605_high,
                      '长城低点买':df_162605_low})

# %%
show_diff_box_plot({'蓝筹高点买':df_005827_high, 
                    '蓝筹低点买':df_005827_low, 
                    '长城高点买':df_162605_high,
                      '长城低点买':df_162605_low})

# %%
show_one_box_plot({'蓝筹高点买':df_005827_high, 
                    '蓝筹低点买':df_005827_low, 
                    '长城高点买':df_162605_high,
                      '长城低点买':df_162605_low})
