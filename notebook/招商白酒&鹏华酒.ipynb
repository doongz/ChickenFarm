# %%
from apollo.src.module.aip_mod import invest_week_with_start_interval
from apollo.src.plot.aip_plot import show_diff_box_plot, show_diff_violin_plot, show_one_box_plot

# %%
# 招商白酒 161725 近期开始买
df_161725_new = invest_week_with_start_interval(code='161725', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 招商白酒 161725 早期开始买
df_161725_old = invest_week_with_start_interval(code='161725', 
                                            start_interval=('2020-01-08', '2020-04-01'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 23:36:23 - aip_service.py - 42 - INFO: 统计完成，161725 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 23:37:34 - aip_service.py - 42 - INFO: 统计完成，161725 每周定投100，起始日区间为('2020-01-08', '2020-04-01'), 结束日为2021-08-09.

# %%
# 鹏华酒 160632 近期开始买
df_160632_new = invest_week_with_start_interval(code='160632', 
                                            start_interval=('2021-01-08', '2021-02-23'), 
                                            end='2021-08-09', 
                                            amount=100)
# 鹏华酒 160632 早期开始买
df_160632_old = invest_week_with_start_interval(code='160632', 
                                            start_interval=('2020-01-08', '2020-04-01'), 
                                            end='2021-08-09', 
                                            amount=100)
# Out:
# 2021-08-12 23:38:04 - aip_service.py - 42 - INFO: 统计完成，160632 每周定投100，起始日区间为('2021-01-08', '2021-02-23'), 结束日为2021-08-09.
# 2021-08-12 23:38:57 - aip_service.py - 42 - INFO: 统计完成，160632 每周定投100，起始日区间为('2020-01-08', '2020-04-01'), 结束日为2021-08-09.

# %%
show_diff_box_plot({'招商白酒-近期买':df_161725_new, 
                    '招商白酒-早期买':df_161725_old,})

# %%
show_diff_box_plot({'鹏华酒-近期买':df_160632_new,
                    '鹏华酒-早期买':df_160632_old})

# %%
show_one_box_plot({'招商白酒-近期买':df_161725_new, 
                    '招商白酒-早期买':df_161725_old, 
                    '鹏华酒-近期买':df_160632_new,
                    '鹏华酒-早期买':df_160632_old})

# %%
show_diff_violin_plot({'招商白酒-近期买':df_161725_new, 
                    '招商白酒-早期买':df_161725_old, 
                    '鹏华酒-近期买':df_160632_new,
                    '鹏华酒-早期买':df_160632_old})
